# %%
23 + ord("C") - ord("Y")
# Out:
# 1

# %%
game = ["A", "B", "C"]

# %%
turn = ['B', 'B']
if turn[0] == turn[1]:
    print("Draw")
elif turn[0]
# Out:
# -2
# 1
# 1

# %%
# -1 perder 0

# %%
ord("B") - ord("Y")
# Out:
# -23

# %%
ord("C") - ord("Z")
# Out:
# -23

# %%
# A = Rock
# B = Paper
# C = Scissors

# X = Rock
# Y = Paper
# Z = Scissors


with open('input.txt') as f:
    data = f.read().splitlines()

data = [data.split(' ') for data in data]
data
# Out:
# [['B', 'Y'],
#  ['A', 'Z'],
#  ['C', 'Z'],
#  ['A', 'Y'],
#  ['A', 'Y'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['A', 'Y'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['A', 'Y'],
#  ['B', 'Z'],
#  ['B', 'Y'],
#  ['A', 'Y'],
#  ['C', 'Y'],
#  ['B', 'X'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['B', 'Y'],
#  ['A', 'Y'],
#  ['B', 'Y'],
#  ['A', 'Y'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['A', 'Y'],
#  ['B', 'X'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['B', 'X'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['B', 'Y'],
#  ['C', 'Z'],
#  ['A', 'X'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['A', 'Z'],
#  ['B', 'X'],
#  ['C', 'Y'],
#  ['C', 'Z'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['A', 'Y'],
#  ['B', 'X'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['B', 'X'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['A', 'Y'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['C', 'X'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['A', 'Z'],
#  ['C', 'Y'],
#  ['B', 'Y'],
#  ['C', 'Z'],
#  ['B', 'X'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['B', 'X'],
#  ['B', 'Y'],
# ...
